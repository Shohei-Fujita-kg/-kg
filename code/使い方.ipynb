# %% [markdown]
# ## 使い方

# %% [markdown]
# ---
#
# このノートブックの目的は使い方の説明です。
#
# リポジトリをローカルに複製して使用します。
#
# [リポジトリをクローンする](https://docs.github.com/ja/repositories/creating-and-managing-repositories/cloning-a-repository)を参考にしてください
#
# または、`README.md`に記載されているダウンロードコマンドを実行するか、GithubのGUIからダウンロードして手動で複製してください
#
# ---

# %% [markdown]
# code内にpythonファイル(.py)を格納する場所`core`を用意しました
#
# 適宜`__init__.py`の`import`にモジュールを追加して使用する関数を呼び出せるようにします
#
# ---

# %% [markdown]
# ローカル環境でcore内の.pyファイルを変更して保存した際に、以前読み込んだモジュールが残っていて変更が反映されない時は、
# ```py
# importlib.reload(util)
# ```
# を実行するとリロードされます

# %%
# 今は関係ないので実行しなくて問題ありません
import importlib
from core import config
importlib.reload(config)

# %% [markdown]
# ### 実行してみよう

# %% [markdown]
# まず試しに`core.util`から`check_available_device`を実行してみましょう

# %% [markdown]
# 実行は三角のボタンをクリックするか、セルをアクティブにして`Shift+Enter`です
#
# ![image.png](attachment:image.png)

# %%
from core import util
# 実行可能なデバイスを探します
util.check_available_device()

# %% [markdown]
# もし実行に失敗した場合`torch`がインストールされていない可能性があります。その場合は以下のコマンドを実行してください

# %%
# !pip install torch torchaudio torchvision

# %% [markdown]
# うまく実行できたらこのノートブックは終了です
#
# 次は`練習1.ipynb`に進みます
