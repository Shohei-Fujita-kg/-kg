# %% [markdown]
# ## [課題] 分類モデルを構築してみよう

# %% [markdown]
# ---
#
# このノートブックの目的はpythonでのデータ処理を体感することです
#
# ここで使用するデータセット(VCTKcorpus)の容量は10GBを超えるため、実行には注意してください
#
# データセットはgithubに含まれないため、git cloneの際にはデータセットを手動で移動してください
#
# デフォルトでのデータセットの保存場所は`data/dataset`となっていますが、適宜変更してください
#
# ```py
# from core import config
# # 保存場所 : {config.f_path}/data/{config.dataset_path}
# config.f_path = "任意のパス"
# config.dataset_path = "任意のパス"
# ```
#
# ---

# %% [markdown]
# [TEDLIUM](https://pytorch.org/audio/stable/generated/torchaudio.datasets.TEDLIUM.html)
#
# [VCTK_092](https://pytorch.org/audio/2.2.0/generated/torchaudio.datasets.VCTK_092.html)

# %%
# データセットのダウンロード
from core import dataset
data = dataset.load_dataset("vctk")
data
